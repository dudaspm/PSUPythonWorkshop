# %% [markdown]
# # Advanced Plotting

# %% [markdown]
# ## Publication Quality Plots

# %% [markdown]
# Let's make this graph look a little better.
#
# Here is our starting graph:

# %%
import matplotlib.pyplot as plt
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

figPSU, ax = plt.subplots()
ax.plot( year, universityPark, label = 'University Park')
ax.plot( year, otherLocs, label = 'Branch Campuses')
ax.plot( year, worldCampus, label = 'World Campus')
ax.set_xlabel( 'Year' )
ax.set_ylabel( 'Enrollment' )
ax.grid()
ax.legend( loc = 2 )
plt.show(figPSU)

# %% [markdown]
# First, let's remove the borders. They don't anything to the graph (clutter).

# %%
import matplotlib.pyplot as plt
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

figPSU, ax = plt.subplots()
ax.plot( year, universityPark, label = 'University Park')
ax.plot( year, otherLocs, label = 'Branch Campuses')
ax.plot( year, worldCampus, label = 'World Campus')
ax.set_xlabel( 'Year' )
ax.set_ylabel( 'Enrollment' )
###################################################
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
###################################################
ax.legend( loc = 2 )
plt.show(figPSU)

# %% [markdown]
# Next, I want to move the labels to the end of the lines.

# %%
import matplotlib.pyplot as plt
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

figPSU, ax = plt.subplots()
ax.plot( year, universityPark, label = 'University Park')
ax.plot( year, otherLocs, label = 'Branch Campuses')
ax.plot( year, worldCampus, label = 'World Campus')
ax.set_xlabel( 'Year' )
ax.set_ylabel( 'Enrollment' )
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
###################################################
ax.text(2020, universityPark[0], 'University Park', horizontalalignment='left', verticalalignment='center')
ax.text(2020, otherLocs[0], 'Branch Campuses', horizontalalignment='left', verticalalignment='center')
ax.text(2020, worldCampus[0], 'World Campuses', horizontalalignment='left', verticalalignment='center')
###################################################
#ax.legend( loc = 2 )
plt.show(figPSU)

# %% [markdown]
# Let's make the Axis Titles larger

# %%
import matplotlib.pyplot as plt
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

figPSU, ax = plt.subplots()
ax.plot( year, universityPark, label = 'University Park')
ax.plot( year, otherLocs, label = 'Branch Campuses')
ax.plot( year, worldCampus, label = 'World Campus')
###################################################
ax.set_xlabel( 'Year' , fontsize=18)
ax.set_ylabel( 'Enrollment' , fontsize=18)
###################################################
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.text(2020, universityPark[0], 'University Park', horizontalalignment='left', verticalalignment='center')
ax.text(2020, otherLocs[0], 'Branch Campuses', horizontalalignment='left', verticalalignment='center')
ax.text(2020, worldCampus[0], 'World Campuses', horizontalalignment='left', verticalalignment='center')

#ax.legend( loc = 2 )
plt.show(figPSU)

# %% [markdown]
# Considering we moved the legend titles to the end of each line. This might not be as important, but if wanted to get some "print friendly colors," we should use colorbrewer.
#
# https://scitools.org.uk/iris/docs/v1.1/userguide/plotting_a_cube.html#brewer-colour-palettes
#
# http://colorbrewer2.org

# %%
import matplotlib.cm as brewer
for colors in brewer.datad:
    print( colors )
# Out:
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Spectral
# Wistia
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spring
# summer
# terrain
# winter
# Accent
# Dark2
# Paired
# Pastel1
# Pastel2
# Set1
# Set2
# Set3
# tab10
# tab20
# tab20b
# tab20c
# Blues_r
# BrBG_r
# BuGn_r
# BuPu_r
# CMRmap_r
# GnBu_r
# Greens_r
# Greys_r
# OrRd_r
# Oranges_r
# PRGn_r
# PiYG_r
# PuBu_r
# PuBuGn_r
# PuOr_r
# PuRd_r
# Purples_r
# RdBu_r
# RdGy_r
# RdPu_r
# RdYlBu_r
# RdYlGn_r
# Reds_r
# Spectral_r
# Wistia_r
# YlGn_r
# YlGnBu_r
# YlOrBr_r
# YlOrRd_r
# afmhot_r
# autumn_r
# binary_r
# bone_r
# brg_r
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as brewer
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

colors = brewer.get_cmap('autumn',3)
figPSU, ax = plt.subplots()
ax.plot( year, universityPark, label = 'University Park', color=colors(0))
ax.plot( year, otherLocs, label = 'Branch Campuses', color=colors(1))
ax.plot( year, worldCampus, label = 'World Campus', color=colors(2))
###################################################
ax.set_xlabel( 'Year' , fontsize=18)
ax.set_ylabel( 'Enrollment' , fontsize=18)
###################################################
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.text(2020, universityPark[0], 'University Park', horizontalalignment='left', verticalalignment='center')
ax.text(2020, otherLocs[0], 'Branch Campuses', horizontalalignment='left', verticalalignment='center')
ax.text(2020, worldCampus[0], 'World Campuses', horizontalalignment='left', verticalalignment='center')

#ax.legend( loc = 2 )
plt.show(figPSU)

# %% [markdown]
# ## Other methods to visualize data

# %% [markdown]
# ### Plotly

# %% [markdown]
# plotly uses a pretty straight-forward approach to graphing. Map values to the x,y coordinate.

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) # initiate notebook for offline plot

import plotly.graph_objs as go
import numpy as np
year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

# Create traces
trace0 = go.Scatter(
    x = year,
    y = universityPark,
    mode = 'lines',
    name = 'University Park'
)
trace1 = go.Scatter(
    x = year,
    y = otherLocs,
    mode = 'lines+markers',
    name = 'Branch Campuses'
)
trace2 = go.Scatter(
    x = year,
    y = worldCampus,
    mode = 'markers',
    name = 'World Campuses'
)
data = [trace0, trace1, trace2]

iplot(data)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %% [markdown]
# ### Altair

# %% [markdown]
# Altair expects a pandas data frame (similar to R)
# We will talk about this more next workshop.

# %%
import altair as alt
import pandas as pd

year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)
# first, format data to fit a data frame
d = {'year': year, 'universityPark': universityPark, 'otherLocs': otherLocs, 'worldCampus': worldCampus}
# second, create the data frame
df = pd.DataFrame(data=d)  
# let's preview the data
print( df.head() )
# Out:
#      year  universityPark  otherLocs  worldCampus
# 0  2017.0         46610.0    37872.0      14301.0
# 1  2016.0         47261.0    38461.0      13411.0
# 2  2015.0         46848.0    38404.0      12242.0
# 3  2014.0         46606.0    38562.0      10805.0
# 4  2013.0         46184.0    38626.0       9631.0

# %% [markdown]
# Again, similar to R. We will "melt" the data. Here is a quick example used from: https://deparkes.co.uk/2016/10/28/reshape-pandas-data-with-melt/

# %%
testData = {'weekday': ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
        'Person 1': [12, 6, 5, 8, 11, 6, 4],
        'Person 2': [10, 6, 11, 5, 8, 9, 12],
        'Person 3': [8, 5, 7, 3, 7, 11, 15]}
print( testData, "\n" )

testDataFrame = pd.DataFrame(testData, columns=['weekday','Person 1', 'Person 2', 'Person 3'])
print( testDataFrame.head(), "\n"  )

testmelted = pd.melt(testDataFrame, id_vars=["weekday"], var_name="Person", value_name="Score")
print( testmelted.head(), "\n" )
# Out:
# {'weekday': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], 'Person 1': [12, 6, 5, 8, 11, 6, 4], 'Person 2': [10, 6, 11, 5, 8, 9, 12], 'Person 3': [8, 5, 7, 3, 7, 11, 15]}
#
#      weekday  Person 1  Person 2  Person 3
# 0     Monday        12        10         8
# 1    Tuesday         6         6         5
# 2  Wednesday         5        11         7
# 3   Thursday         8         5         3
# 4     Friday        11         8         7
#
#      weekday    Person  Score
# 0     Monday  Person 1     12
# 1    Tuesday  Person 1      6
# 2  Wednesday  Person 1      5
# 3   Thursday  Person 1      8
# 4     Friday  Person 1     11

# %% [markdown]
# Back to our data.

# %%
melted = pd.melt(df, id_vars=["year"], var_name="location", value_name="enrollment")
print( melted.head() )
# Out:
#      year        location  enrollment
# 0  2017.0  universityPark     46610.0
# 1  2016.0  universityPark     47261.0
# 2  2015.0  universityPark     46848.0
# 3  2014.0  universityPark     46606.0
# 4  2013.0  universityPark     46184.0

# %% [markdown]
# Now use altair to create line chart for all three locations.

# %%
# to use with Jupyter notebook (not JupyterLab) run the following
alt.renderers.enable('notebook')

# load a simple dataset as a pandas DataFrame
# The basic line
alt.Chart(melted).mark_line(interpolate='basis').encode(
    x='year',
    y='enrollment',
    color='location'
)
# Out:
# ---------------------------------------------------------------------------
# NoSuchEntryPoint                          Traceback (most recent call last)
# ~/Library/Python/3.6/lib/python/site-packages/altair/utils/plugin_registry.py in _enable(self, name, **options)
#     133             try:
# --> 134                 ep = entrypoints.get_single(self.entry_point_group, name)
#     135             except entrypoints.NoSuchEntryPoint:
#
# /usr/local/lib/python3.6/site-packages/entrypoints.py in get_single(group, name, path)
#     185
# --> 186     raise NoSuchEntryPoint(group, name)
#     187
#
# NoSuchEntryPoint: No 'notebook' entry point found in group 'altair.vegalite.v2.renderer'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-38b563f5be29> in <module>()
#       1 # to use with Jupyter notebook (not JupyterLab) run the following
# ...

# %% [markdown]
# The last method is definetly a bit more complex, but by far my most suggested method. This is utilizing the fact that Jupyter is a browser based system. So why not use JavaScript?

# %% [markdown]
# First, we need to change up the data a bit to fit this D3.js graph.

# %% [markdown]
# This approach uses D3.js (https://d3js.org/). Again, D3.js has a pretty big learning curve, but will enivably provide the most functionality in the long run (also, free/open-source).

# %%
from IPython.display import HTML
from IPython.display import Javascript

year, universityPark, otherLocs, worldCampus, totPSU = np.loadtxt('pennStateEnroll.dat', unpack=True, comments='#', skiprows=2)

# we are creating three bins for the data
allData = []

for i in range(len(year)):
    allData.append([year[i], universityPark[i],"University Park"])
    allData.append([year[i], otherLocs[i],"Other Locations"])
    allData.append([year[i], worldCampus[i],"World Campus"])


for i in allData[0:5]:
    print( i )
Javascript("""window.data={};""".format(allData))
# Out:
# [2017.0, 46610.0, 'University Park']
# [2017.0, 37872.0, 'Other Locations']
# [2017.0, 14301.0, 'World Campus']
# [2016.0, 47261.0, 'University Park']
# [2016.0, 38461.0, 'Other Locations']

# %% [markdown]
# Next we need to create the actual lines/marks (paths/circles)

# %%
# %%javascript
# element.append('<div id="graph" style="min-width: 800px; height: 400px; margin: 0 auto"></div>');
# require.config({paths: {d3: "//d3js.org/d3.v4.min",}});
#
# require(["d3"], function(d3) {
#     // sorting the data by date
#     data.sort(function(a, b){return a[0] - b[0]});
#
#     // Use this to keep the screen clean
#     d3.select("div#graph").selectAll("*").remove();
#
#     // declare width/height
#     var width = 800, height = 400, margin = 60;
#
#     //define the x range/domain
#     var x = d3.scaleLinear().range([50, width-50]).domain(d3.extent(data, d=>d[0]));
#
#     //define the y range/domain
#     var y = d3.scaleLinear().range([height-margin, margin]).domain(d3.extent(data,d=>d[1]));
#
#     // d3's line generator
#     var line = d3.line()
#         .x(function(d) { return x(d[0]); }) // set the x values for the line generator
#         .y(function(d) { return y(d[1]); }) // set the y values for the line generator
#         .curve(d3.curveMonotoneX) // apply smoothing to the line
#     var color = d3.scaleOrdinal(d3.schemeCategory10); // Additional details on Color: https://github.com/d3/d3-scale-chromatic
#
#     // first, add a container for the SVG object
#     var svg = d3.select("div#graph").append("svg")
#         .attr("width", width+"px")
#         .attr("height", height+"px");
#
#     // create the x axis in a group tag
#     svg.append("g")
#         .attr("class", "x axis")
#         .attr("transform", "translate(0," + (height-margin) + ")")
#         .call(d3.axisBottom(x)); // Create an axis component with d3.axisBottom
#
#     // text for label
#     svg.append("text")
#         .attr("transform","translate(" + (width/2) + " ," + (height - 20) + ")")
#         .style("text-anchor", "middle")
#         .text("Date");
#
#     // create the y axis in a group tag
#     svg.append("g")
#         .attr("class", "y axis")
#         .attr("transform", "translate("+ (margin) + ",0)")
#         .call(d3.axisLeft(y)) // Create an axis component with d3.axisLeft
#
#     // text for label
#     svg.append("text")
#         .attr("transform", "rotate(-90)")
#         .attr("y", 10)
#         .attr("x", - (height / 2))
#         .style("text-anchor", "middle")
#         .text("Value");
#
#     // we have 3 plots, so we will group these together using nest
#     svg.selectAll("path.line").data(d3.nest().key(function(d) { return d[2]; }).entries(data)) // binds data to the line
#         .enter().append("path")
#         .attr("class", "line") // Assign a class for styling
#         .attr("d",d=> line(d.values)) // Calls the line generator
#         .style("fill","none")
#         .style("stroke",(d,i)=>color(d.key))
#
#      // adding circle for each mark
#     svg.selectAll("circle.point").data(data) // binds data to the line
#         .enter().append("circle")
#         .attr("class", "point") // Assign a class for styling
#         .attr("cx", function(d) {return x(d[0]) })
#         .attr("cy", function(d) { return y(d[1]) })
#         .attr("r", 2)
#         .style("stroke",d=>color(d[2]))
#         .style("fill",d=>color(d[2]))
# })

# %% [markdown]
# Where D3.js starts to shine is when we utilize it with transitions (animations).

# %%
# %%javascript
# element.append('<div id="graph2" style="min-width: 800px; height: 400px; margin: 0 auto"></div>');
# require.config({paths: {d3: "//d3js.org/d3.v4.min",}});
#
# require(["d3"], function(d3) {
#     // sorting the data by date
#     data.sort(function(a, b){return a[0] - b[0]});
#
#     // Use this to keep the screen clean
#     d3.select("div#graph2").selectAll("*").remove();
#
#     // declare width/height
#     var width = 800, height = 400, margin = 60;
#
#     //define the x range/domain
#     var x = d3.scaleLinear().range([50, width-50]).domain(d3.extent(data, d=>d[0]));
#
#     //define the y range/domain
#     var y = d3.scaleLinear().range([height-margin, margin]).domain(d3.extent(data,d=>d[1]));
#
#     // d3's line generator
#     var line = d3.line()
#         .x(function(d) { return x(d[0]); }) // set the x values for the line generator
#         .y(function(d) { return y(d[1]); }) // set the y values for the line generator
#         .curve(d3.curveMonotoneX) // apply smoothing to the line
#     var color = d3.scaleOrdinal(d3.schemeCategory10); // Additional details on Color: https://github.com/d3/d3-scale-chromatic
#
#     // first, add a container for the SVG object
#     var svg = d3.select("div#graph2").append("svg")
#         .attr("width", width+"px")
#         .attr("height", height+"px");
#
#     // create the x axis in a group tag
#     svg.append("g")
#         .attr("class", "x axis")
#         .attr("transform", "translate(0," + (height-margin) + ")")
#         .call(d3.axisBottom(x)); // Create an axis component with d3.axisBottom
#
#     // add text for label
#     svg.append("text")
#         .attr("transform","translate(" + (width/2) + " ," + (height - 20) + ")")
#         .style("text-anchor", "middle")
#         .text("Date");
#
#     // create the y axis in a group tag
#     svg.append("g")
#         .attr("class", "y axis")
#         .attr("transform", "translate("+ (margin) + ",0)")
#         .call(d3.axisLeft(y)) // Create an axis component with d3.axisLeft
#
#     // add text for label
#     svg.append("text")
#         .attr("transform", "rotate(-90)")
#         .attr("y", 10)
#         .attr("x", - (height / 2))
#         .style("text-anchor", "middle")
#         .text("Value");
#
#     // we have 3 plots, so we will group these together
#     svg.selectAll("path.line").data(d3.nest().key(function(d) { return d[2]; }).entries(data)) // 10. Binds data to the line
#         .enter().append("path")
#         .attr("class", "line") // Assign a class for styling
#         .attr("d",d=> line(d.values)) // Calls the line generator
#         //.attr("d",d=> console.log(d.values)) // 11. Calls the line generator
#         .style("fill","none")
#         .style("stroke",(d,i)=>color(d.key))
#         .transition()
#         .duration(2000)
#         .attrTween("stroke-dasharray", function() {
#             var len = this.getTotalLength();
#             return function(t) { return (d3.interpolateString("0," + len, len + ",0"))(t) };
#            })
#
#     // adding circle for each mark
#     svg.selectAll("circle.point").data(data) // 10. Binds data to the line
#         .enter().append("circle")
#         .attr("class", "point") // Assign a class for styling
#         .attr("cx", function(d) {return x(d[0]) })
#         .attr("cy", function(d) { return y(d[1]) })
#         .attr("r", 0)
#         .style("stroke",d=>color(d[2]))
#         .style("fill",d=>color(d[2]))
#         .transition()
#         .duration(2000)
#         .delay((d,i)=>(d[0]-d3.min(data,d=>d[0]))*40)
#         .attr("r", 2)
# })
